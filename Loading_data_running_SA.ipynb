# %% [markdown]
# # Example preparation of data before Simulated Annealing and then firing up the algorithm
# Here, we prepare the data from CHAMP and NucleaSeq according to the S.I. of our manuscript.

# %%
import pandas as pd 
import numpy as np 

import os 
cwd = os.getcwd()
#path = '\\Users\\mdepk\\Documents\\CRISPR_kinetic_model\\'
path=cwd+'\\'

import sys
sys.path.append(path)
sys.path.append(path+"simmulated_Annealing_fit\\")
sys.path.append(path+"model\\")

from preprocessing_data import sequence_averaged_weighted as prepData
from model.CRISPRclass import CRISPR 

import SimmulatedAnnealing_DEP as SAfit
import objective_functions as ObjFunc
from time import time
from datetime import datetime

from importlib import reload
reload(prepData);

# %% [markdown]
# ## Loading the experimental data
# It is less important to figure out exactly how this is done, more important that it produces a sequence averaged file to input in simulated annealing algorithm

# %%
'''
Let's prepare a dataset with sequence averaged data for spCas9 NucleaSeq and CHAMP 
(equivalent to that used for manuscript)
'''

dataPath =  path+'data_experiment'
fileNucSeq = os.path.join(dataPath, 'NucleaSeq_dataset.csv')
fileCHAMP = os.path.join(dataPath, 'CHAMP_dataset.csv' )


Cas9 = CRISPR(guide_length=20,
                  PAM_length=3,
                  PAM_sequence='NGG')


targetE = 'GACGCATAAAGATGAGACGCTGG'

NucleaSeqData = prepData.WA_NucleaSeq_DEP(filename=fileNucSeq, Cas=Cas9, on_target=targetE)
CHAMPData = prepData.WA_CHAMP_DEP(filename=fileCHAMP, Cas=Cas9, on_target=targetE)
SeqAvgData = NucleaSeqData.merge(CHAMPData, on=['sequence','mismatch_pattern','mismatch_number']   )


saveFile = os.path.join(dataPath, 'sequence_averaged_CHAMP_NucleaSeq_DEP.csv')
SeqAvgData.to_csv(saveFile, index=False )

# %% [markdown]
# # Setting up the simulated annealing run

# %%
from objective_functions import chi_sqrd_NucleaSeq_CHAMP as chi2


###################################################################################
# /*   bounds on parameters + initial guess                                       #
#   the latter is actually irrelevant, but just for consistency/nice movies :-) *\#
###################################################################################
# --- bounds on parameters  and initial guess (the latter is actually irrelevant) ---

upper_bnd = [5.] + [10.] * 20 + [5.5] * 20 + [5.] + [3.] + [4.]
lower_bnd = [-1.] + [-10.] * 20 + [4.5] * 20 + [-5.] + [1.] + [-1.]

# upper_bnd = [5.] + [10.] * 20 + [10.] * 20 + [5.] + [3.] + [4.]
# lower_bnd = [-1.] + [-10.] * 20 + [0.] * 20 + [-5.] + [1.] + [-1.]
#initial_guess = [2.] + [0.] * 20 + [5.] * 20 + [0.] + [2.] + [2.]


#######################################################
# /*   Cost function/Objective function for SA-fit  *\#
 #######################################################
# --- You made your objective function, assign it here
# (the funcArgs will be unpacked within your own function, so use the same conventions over here) ---
funcArgs = {}
funcArgs["guide_sequence"] = 'GACGCATAAAGATGAGACGCTGG'
funcArgs["ID_Cas"] = "Clv_Saturated_general_energies_v2"
funcArgs["ID_dCas"] = "general_energies_no_kPR"
funcArgs["Cas"] = CRISPR(guide_length=20,
                         PAM_length=3,
                         PAM_sequence='NGG')
funcArgs["concentration_params"] = 10.  # To get the same as Stijn
myObjectiveFunc = chi2

##############################################
# /*   Input experimental data             *\#
##############################################
dataPath = os.path.join(path,'data_experiment')
fileName = os.path.join(dataPath, 'sequence_averaged_CHAMP_NucleaSeq_DEP.csv')  #<---- This is where our seqeunced average file is loaded
SeqAvgData = pd.read_csv(fileName)

xdata = np.array(SeqAvgData['sequence'])

y1 = np.array(SeqAvgData['cleavage_rate_log10'])
y2 = np.array(SeqAvgData['dissociation_const_log_e'])
ydata = np.array(list(zip(y1, y2)))

e1 = np.array(SeqAvgData['cleavage_rate_error_log10'])
e2 = np.array(SeqAvgData['dissociation_const_error_log_e'])
yerr = np.array(list(zip(e1, e2)))

# %% [markdown]
# # generate a run definition from time and date

# %%
now = datetime.now() # current date and time
run_def= now.strftime("%Y%m%d-%H%M")
print(run_def)
# Out:
# 20200921-1953

# %%
run_def="20200921-1953"

# %%
fileResults = path+"DEP\\Run_"+run_def+"_Search_State.txt"
print(fileResults)
# Out:
# C:\Users\mdepk\Documents\CRISPR_kinetic_model\DEP\Run_20200921-1953_Search_State.txt

# %% [markdown]
# ## Running an optimization from start

# %%
##############################################
# /*   Call the Simulated Annealing code   *\#
##############################################

# The parameters are here stored as an array as follows:
# \Delta F_PAM, \Delta F_1, ...,\Delta F_20, \Delta Fmm_1, ..., \Delta Fmm_20, log10(kon), log10(kf), log10(kcat)
#                   ontarget energies       |       mismatch penalties      | on rate, forward rate, cleavage rate

# --- unpack the command line arguments ---

fileResults = path+"DEP\\Run_"+run_def+"_Search_State.txt"
fileMonitor = path+"DEP\\Run_"+run_def+"_Search_Monitor.txt"
fileInitMonitor = path+"DEP\\Run_"+run_def+"_Initiation_Monitor.txt"

initial_guess = [2.] + list(1*(np.random.rand(20)-0.5)) + list(5+1*(np.random.rand(20)-0.5)) + [0.] + [2.] + [2.]
initial_guess = [2.] + [0.] * 20 + [5.] * 20 + [0.] + [2.] + [2.]

t1 = time()
best_fit = SAfit.sim_anneal_fit_DEP(xdata=xdata,
                                ydata=ydata,
                                yerr=yerr,
                                Xstart=initial_guess,
                                lwrbnd=lower_bnd,
                                upbnd=upper_bnd,
                                objective_function=myObjectiveFunc,
                                objective_function_args=funcArgs,
                                Tstart=400000.,  #Ball park estimate from test run (just for speed up)
                                delta=0.2,
                                delta_DEP=0.8,
                                tol=1E-5,
                                Tfinal=0.0,
                                adjust_factor=1.3,
                                cooling_rate=0.99,
                                N_int=100,
                                AR_low=40,
                                AR_high=60,
                                use_multiprocessing=True,
                                nprocs=19,  # HPC05 has computers with 20 cores. 1 core reserved for THIS function
                                output_file_results=fileResults,
                                output_file_monitor=fileMonitor,
                                output_file_init_monitor=fileInitMonitor,InitEQ=True, ReStart=False)

t2 = time()

# the following line will get printed into a specific text file when running on cluster.
print("Time elapsed: ", (t2-t1)/3600., "hrs")
# Out:
# ====================================================================================================================================
# > Starting initiation loop the barrier-buster moves
# >- acceptence  35.0 % at temperature 400000.0  and barrier-busting power  0.8
# >- acceptence  39.0 % at temperature 520000.0  and barrier-busting power  0.8
# >- acceptence  47.0 % at temperature 676000.0  and barrier-busting power  0.8
#
# ====================================================================================================================================
# > Starting initiation loop for the free-energy moves
# >- acceptence  34.0 % at temperature  676000.0  and step  0.2
# >- acceptence  20.0 % at temperature  676000.0  and step  0.15384615384615385
# >- acceptence  30.0 % at temperature  676000.0  and step  0.1183431952662722
# >- acceptence  40.0 % at temperature  676000.0  and step  0.09103322712790168
#
# ====================================================================================================================================
# > Initiating cool-down at
# >--temp:   676000.0
# >--energy step:   0.09103322712790168
# >--bb power step:   0.8
# ------------------------------------------------------------------------------------------------------------------------------------
# |-(over)writing run to C:\Users\mdepk\Documents\CRISPR_kinetic_model\DEP\Run_20200921-1953_Search_State.txt
#  /-acceptance  46.0 % at energy-step size  0.09103322712790168
# /--acceptance  42.0 %  at barrier-busting power  0.8
# |--Time cost  4.96015498638153 minutes
# <--Equilibration reached. Updating and saving search state at T= 676000.0  and chi2= 28608999.21073712
# C:\Users\mdepk\Documents\CRISPR_kinetic_model\simmulated_Annealing_fit\SimmulatedAnnealing_DEP.py:519: RuntimeWarning: invalid value encountered in double_scalars
#   tolerance_low_enough = abs(SA.ReldE) / SA.average_energy < SA.Tolerance
# C:\Users\mdepk\Documents\CRISPR_kinetic_model\simmulated_Annealing_fit\SimmulatedAnnealing_DEP.py:539: RuntimeWarning: invalid value encountered in double_scalars
#   SA.Monitor['(last recorded) relative change average energy'] = abs(SA.average_energy - Eavg) / SA.average_energy
#  /-acceptance  46.0 % at energy-step size  0.09103322712790168
# /--acceptance  48.0 %  at barrier-busting power  0.8
# |--Time cost  4.463866198062897 minutes
# <--Equilibration reached. Updating and saving search state at T= 669240.0  and chi2= 24754424.264102515
#  /-acceptance  37.0 % at energy-step size  0.09103322712790168
# /--acceptance  56.00000000000001 %  at barrier-busting power  0.8
# |--Time cost  4.538910480340322 minutes
#  /-acceptance  54.0 % at energy-step size  0.07002555932915513
# /--acceptance  57.99999999999999 %  at barrier-busting power  0.8
# |--Time cost  4.159367656707763 minutes
# <--Equilibration reached. Updating and saving search state at T= 662547.6  and chi2= 22116735.19316066
#  /-acceptance  48.0 % at energy-step size  0.07002555932915513
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.8
# |--Time cost  4.059824240207672 minutes
# <--Equilibration reached. Updating and saving search state at T= 655922.124  and chi2= 19125473.091540154
#  /-acceptance  46.0 % at energy-step size  0.07002555932915513
# /--acceptance  48.0 %  at barrier-busting power  0.8
# |--Time cost  4.03904793659846 minutes
# <--Equilibration reached. Updating and saving search state at T= 649362.90276  and chi2= 19808171.43436698
#  /-acceptance  46.0 % at energy-step size  0.07002555932915513
# /--acceptance  53.0 %  at barrier-busting power  0.8
# |--Time cost  4.177817134062449 minutes
# <--Equilibration reached. Updating and saving search state at T= 642869.2737323999  and chi2= 19799715.94424801
#  /-acceptance  40.0 % at energy-step size  0.07002555932915513
# /--acceptance  47.0 %  at barrier-busting power  0.8
# |--Time cost  4.060342748959859 minutes
# <--Equilibration reached. Updating and saving search state at T= 636440.5809950759  and chi2= 17065124.24170358
#  /-acceptance  55.00000000000001 % at energy-step size  0.07002555932915513
# /--acceptance  54.0 %  at barrier-busting power  0.8
# |--Time cost  4.42786180973053 minutes
# <--Equilibration reached. Updating and saving search state at T= 630076.1751851251  and chi2= 17498425.84695892
#  /-acceptance  44.0 % at energy-step size  0.07002555932915513
# /--acceptance  56.99999999999999 %  at barrier-busting power  0.8
# |--Time cost  4.865968517462412 minutes
# <--Equilibration reached. Updating and saving search state at T= 623775.4134332738  and chi2= 16619166.051147144
#  /-acceptance  54.0 % at energy-step size  0.07002555932915513
# /--acceptance  56.99999999999999 %  at barrier-busting power  0.8
# |--Time cost  5.206646291414897 minutes
# <--Equilibration reached. Updating and saving search state at T= 617537.659298941  and chi2= 21504459.361483645
#  /-acceptance  43.0 % at energy-step size  0.07002555932915513
# /--acceptance  59.0 %  at barrier-busting power  0.8
# |--Time cost  5.465827043851217 minutes
# <--Equilibration reached. Updating and saving search state at T= 611362.2827059516  and chi2= 23045871.139186114
#  /-acceptance  52.0 % at energy-step size  0.07002555932915513
# /--acceptance  51.0 %  at barrier-busting power  0.8
# |--Time cost  5.856993456681569 minutes
# <--Equilibration reached. Updating and saving search state at T= 605248.6598788921  and chi2= 21967890.39969014
#  /-acceptance  46.0 % at energy-step size  0.07002555932915513
# /--acceptance  46.0 %  at barrier-busting power  0.8
# |--Time cost  5.85649452606837 minutes
# <--Equilibration reached. Updating and saving search state at T= 599196.1732801032  and chi2= 18281415.471357666
#  /-acceptance  44.0 % at energy-step size  0.07002555932915513
# /--acceptance  49.0 %  at barrier-busting power  0.8
# |--Time cost  6.195696870485942 minutes
# <--Equilibration reached. Updating and saving search state at T= 593204.2115473022  and chi2= 19748930.949461885
#  /-acceptance  45.0 % at energy-step size  0.07002555932915513
# /--acceptance  51.0 %  at barrier-busting power  0.8
# |--Time cost  6.316018839677175 minutes
# <--Equilibration reached. Updating and saving search state at T= 587272.1694318291  and chi2= 18557284.168550834
#  /-acceptance  44.0 % at energy-step size  0.07002555932915513
# /--acceptance  44.0 %  at barrier-busting power  0.8
# |--Time cost  6.05520593325297 minutes
# <--Equilibration reached. Updating and saving search state at T= 581399.4477375108  and chi2= 18228696.89574463
#  /-acceptance  56.99999999999999 % at energy-step size  0.07002555932915513
# /--acceptance  49.0 %  at barrier-busting power  0.8
# |--Time cost  5.811556295553843 minutes
# <--Equilibration reached. Updating and saving search state at T= 575585.4532601357  and chi2= 17661438.04098172
#  /-acceptance  45.0 % at energy-step size  0.07002555932915513
# /--acceptance  45.0 %  at barrier-busting power  0.8
# |--Time cost  5.895957907040914 minutes
# <--Equilibration reached. Updating and saving search state at T= 569829.5987275344  and chi2= 19199272.24915476
#  /-acceptance  56.00000000000001 % at energy-step size  0.07002555932915513
# /--acceptance  48.0 %  at barrier-busting power  0.8
# |--Time cost  6.88129692475001 minutes
# <--Equilibration reached. Updating and saving search state at T= 564131.3027402591  and chi2= 17851885.1275496
#  /-acceptance  48.0 % at energy-step size  0.07002555932915513
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.8
# |--Time cost  5.250954838593801 minutes
# <--Equilibration reached. Updating and saving search state at T= 558489.9897128565  and chi2= 17978784.183033593
#  /-acceptance  44.0 % at energy-step size  0.07002555932915513
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.8
# |--Time cost  4.3951788147290545 minutes
# <--Equilibration reached. Updating and saving search state at T= 552905.0898157279  and chi2= 18618135.46053138
#  /-acceptance  40.0 % at energy-step size  0.07002555932915513
# /--acceptance  47.0 %  at barrier-busting power  0.8
# |--Time cost  4.430404516061147 minutes
# <--Equilibration reached. Updating and saving search state at T= 547376.0389175706  and chi2= 17000248.221377112
#  /-acceptance  34.0 % at energy-step size  0.07002555932915513
# /--acceptance  56.99999999999999 %  at barrier-busting power  0.8
# |--Time cost  4.344763505458832 minutes
#  /-acceptance  51.0 % at energy-step size  0.05386581486858087
# /--acceptance  54.0 %  at barrier-busting power  0.8
# |--Time cost  4.33250302473704 minutes
# <--Equilibration reached. Updating and saving search state at T= 541902.2785283949  and chi2= 18636382.411449924
#  /-acceptance  54.0 % at energy-step size  0.05386581486858087
# /--acceptance  50.0 %  at barrier-busting power  0.8
# |--Time cost  4.218754824002584 minutes
# <--Equilibration reached. Updating and saving search state at T= 536483.2557431109  and chi2= 20504814.131380945
#  /-acceptance  51.0 % at energy-step size  0.05386581486858087
# /--acceptance  54.0 %  at barrier-busting power  0.8
# |--Time cost  4.1455100774765015 minutes
# <--Equilibration reached. Updating and saving search state at T= 531118.4231856798  and chi2= 20961413.71104986
#  /-acceptance  52.0 % at energy-step size  0.05386581486858087
# /--acceptance  51.0 %  at barrier-busting power  0.8
# |--Time cost  4.134259804089864 minutes
# <--Equilibration reached. Updating and saving search state at T= 525807.238953823  and chi2= 21100163.19576047
#  /-acceptance  59.0 % at energy-step size  0.05386581486858087
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.8
# |--Time cost  4.18807315826416 minutes
# <--Equilibration reached. Updating and saving search state at T= 520549.16656428477  and chi2= 20094656.679505758
#  /-acceptance  47.0 % at energy-step size  0.05386581486858087
# /--acceptance  44.0 %  at barrier-busting power  0.8
# |--Time cost  4.115918874740601 minutes
# <--Equilibration reached. Updating and saving search state at T= 515343.67489864194  and chi2= 19614133.157147903
#  /-acceptance  59.0 % at energy-step size  0.05386581486858087
# /--acceptance  47.0 %  at barrier-busting power  0.8
# |--Time cost  3.942160594463348 minutes
# <--Equilibration reached. Updating and saving search state at T= 510190.2381496555  and chi2= 20788470.604489695
#  /-acceptance  52.0 % at energy-step size  0.05386581486858087
# /--acceptance  46.0 %  at barrier-busting power  0.8
# |--Time cost  4.067351615428924 minutes
# <--Equilibration reached. Updating and saving search state at T= 505088.33576815896  and chi2= 21101172.840701483
#  /-acceptance  52.0 % at energy-step size  0.05386581486858087
# /--acceptance  52.0 %  at barrier-busting power  0.8
# |--Time cost  4.09109814564387 minutes
# <--Equilibration reached. Updating and saving search state at T= 500037.4524104774  and chi2= 19881122.550984796
#  /-acceptance  47.0 % at energy-step size  0.05386581486858087
# /--acceptance  47.0 %  at barrier-busting power  0.8
# |--Time cost  4.11571428378423 minutes
# <--Equilibration reached. Updating and saving search state at T= 495037.07788637263  and chi2= 19308426.69681246
#  /-acceptance  52.0 % at energy-step size  0.05386581486858087
# /--acceptance  47.0 %  at barrier-busting power  0.8
# |--Time cost  3.999644088745117 minutes
# <--Equilibration reached. Updating and saving search state at T= 490086.7071075089  and chi2= 20737961.4913315
#  /-acceptance  50.0 % at energy-step size  0.05386581486858087
# /--acceptance  53.0 %  at barrier-busting power  0.8
# |--Time cost  4.017707232634226 minutes
# <--Equilibration reached. Updating and saving search state at T= 485185.84003643383  and chi2= 18835404.23257064
#  /-acceptance  55.00000000000001 % at energy-step size  0.05386581486858087
# /--acceptance  48.0 %  at barrier-busting power  0.8
# |--Time cost  3.928902848561605 minutes
# <--Equilibration reached. Updating and saving search state at T= 480333.9816360695  and chi2= 20629638.35505927
#  /-acceptance  56.00000000000001 % at energy-step size  0.05386581486858087
# /--acceptance  41.0 %  at barrier-busting power  0.8
# |--Time cost  4.0476834336916605 minutes
# <--Equilibration reached. Updating and saving search state at T= 475530.6418197088  and chi2= 17001908.29344758
#  /-acceptance  56.99999999999999 % at energy-step size  0.05386581486858087
# /--acceptance  40.0 %  at barrier-busting power  0.8
# |--Time cost  3.9116628050804136 minutes
# <--Equilibration reached. Updating and saving search state at T= 470775.3354015117  and chi2= 19266939.225037564
#  /-acceptance  49.0 % at energy-step size  0.05386581486858087
# /--acceptance  45.0 %  at barrier-busting power  0.8
# |--Time cost  3.9572567701339723 minutes
# <--Equilibration reached. Updating and saving search state at T= 466067.5820474966  and chi2= 19673403.763099864
#  /-acceptance  43.0 % at energy-step size  0.05386581486858087
# /--acceptance  42.0 %  at barrier-busting power  0.8
# |--Time cost  4.054409889380137 minutes
# <--Equilibration reached. Updating and saving search state at T= 461406.9062270216  and chi2= 20070053.445727162
#  /-acceptance  48.0 % at energy-step size  0.05386581486858087
# /--acceptance  40.0 %  at barrier-busting power  0.8
# |--Time cost  4.054709951082866 minutes
# <--Equilibration reached. Updating and saving search state at T= 456792.83716475137  and chi2= 20473020.059637666
#  /-acceptance  49.0 % at energy-step size  0.05386581486858087
# /--acceptance  54.0 %  at barrier-busting power  0.8
# |--Time cost  3.9488591074943544 minutes
# <--Equilibration reached. Updating and saving search state at T= 452224.9087931039  and chi2= 19802485.080088828
#  /-acceptance  50.0 % at energy-step size  0.05386581486858087
# /--acceptance  52.0 %  at barrier-busting power  0.8
# |--Time cost  4.012924961249033 minutes
# <--Equilibration reached. Updating and saving search state at T= 447702.6597051728  and chi2= 23033934.555912346
#  /-acceptance  57.99999999999999 % at energy-step size  0.05386581486858087
# /--acceptance  50.0 %  at barrier-busting power  0.8
# |--Time cost  4.047297239303589 minutes
# <--Equilibration reached. Updating and saving search state at T= 443225.6331081211  and chi2= 19637331.312616028
#  /-acceptance  47.0 % at energy-step size  0.05386581486858087
# /--acceptance  35.0 %  at barrier-busting power  0.8
# |--Time cost  4.030503650506337 minutes
#  /-acceptance  42.0 % at energy-step size  0.05386581486858087
# /--acceptance  50.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.029910413424174 minutes
# <--Equilibration reached. Updating and saving search state at T= 438793.3767770399  and chi2= 16913846.444663752
#  /-acceptance  55.00000000000001 % at energy-step size  0.05386581486858087
# /--acceptance  46.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.022178467114767 minutes
# <--Equilibration reached. Updating and saving search state at T= 434405.4430092695  and chi2= 17785559.46359124
#  /-acceptance  61.0 % at energy-step size  0.05386581486858087
# /--acceptance  60.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  3.9476789355278017 minutes
#  /-acceptance  35.0 % at energy-step size  0.07002555932915513
# /--acceptance  46.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.062512894471486 minutes
#  /-acceptance  45.0 % at energy-step size  0.05386581486858087
# /--acceptance  48.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.094192906220754 minutes
# <--Equilibration reached. Updating and saving search state at T= 430061.3885791768  and chi2= 14024840.342430724
#  /-acceptance  46.0 % at energy-step size  0.05386581486858087
# /--acceptance  57.99999999999999 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.281962899367015 minutes
# <--Equilibration reached. Updating and saving search state at T= 425760.774693385  and chi2= 15727078.623700809
#  /-acceptance  53.0 % at energy-step size  0.05386581486858087
# /--acceptance  47.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.172727513313293 minutes
# <--Equilibration reached. Updating and saving search state at T= 421503.1669464511  and chi2= 17246912.562061187
#  /-acceptance  55.00000000000001 % at energy-step size  0.05386581486858087
# /--acceptance  52.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.328847261269887 minutes
# <--Equilibration reached. Updating and saving search state at T= 417288.13527698664  and chi2= 16700013.835454702
#  /-acceptance  53.0 % at energy-step size  0.05386581486858087
# /--acceptance  44.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.513160987695058 minutes
# <--Equilibration reached. Updating and saving search state at T= 413115.2539242168  and chi2= 16772819.949856482
#  /-acceptance  28.999999999999996 % at energy-step size  0.05386581486858087
# /--acceptance  53.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.580483059088389 minutes
#  /-acceptance  9.0 % at energy-step size  0.04143524220660067
# /--acceptance  61.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.333631527423859 minutes
#  /-acceptance  44.0 % at energy-step size  0.03187326323584667
# /--acceptance  42.0 %  at barrier-busting power  0.8
# |--Time cost  4.045725170771281 minutes
# <--Equilibration reached. Updating and saving search state at T= 408984.1013849746  and chi2= 20430304.90687648
#  /-acceptance  63.0 % at energy-step size  0.03187326323584667
# /--acceptance  48.0 %  at barrier-busting power  0.8
# |--Time cost  4.070308335622152 minutes
#  /-acceptance  10.0 % at energy-step size  0.04143524220660067
# /--acceptance  40.0 %  at barrier-busting power  0.8
# |--Time cost  4.389935890833537 minutes
#  /-acceptance  56.99999999999999 % at energy-step size  0.03187326323584667
# /--acceptance  37.0 %  at barrier-busting power  0.8
# |--Time cost  4.353163393338521 minutes
#  /-acceptance  48.0 % at energy-step size  0.03187326323584667
# /--acceptance  48.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.427871259053548 minutes
# <--Equilibration reached. Updating and saving search state at T= 404894.26037112484  and chi2= 17068972.77028897
#  /-acceptance  52.0 % at energy-step size  0.03187326323584667
# /--acceptance  48.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.317218192418417 minutes
# <--Equilibration reached. Updating and saving search state at T= 400845.31776741357  and chi2= 16354052.352300514
#  /-acceptance  59.0 % at energy-step size  0.03187326323584667
# /--acceptance  56.99999999999999 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.2563171029090885 minutes
# <--Equilibration reached. Updating and saving search state at T= 396836.8645897394  and chi2= 17864313.111352637
#  /-acceptance  66.0 % at energy-step size  0.03187326323584667
# /--acceptance  48.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.329078114032745 minutes
#  /-acceptance  56.00000000000001 % at energy-step size  0.04143524220660067
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.20648592710495 minutes
# <--Equilibration reached. Updating and saving search state at T= 392868.495943842  and chi2= 19999003.086217843
#  /-acceptance  57.99999999999999 % at energy-step size  0.04143524220660067
# /--acceptance  50.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.249622499942779 minutes
# <--Equilibration reached. Updating and saving search state at T= 388939.8109844036  and chi2= 17875834.31760683
#  /-acceptance  60.0 % at energy-step size  0.04143524220660067
# /--acceptance  54.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.34456373055776 minutes
# <--Equilibration reached. Updating and saving search state at T= 385050.4128745596  and chi2= 19762203.868471324
#  /-acceptance  61.0 % at energy-step size  0.04143524220660067
# /--acceptance  48.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.103075154622396 minutes
#  /-acceptance  56.00000000000001 % at energy-step size  0.05386581486858087
# /--acceptance  59.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.313749837875366 minutes
# <--Equilibration reached. Updating and saving search state at T= 381199.908745814  and chi2= 17844399.97617259
#  /-acceptance  52.0 % at energy-step size  0.05386581486858087
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.175583191712698 minutes
# <--Equilibration reached. Updating and saving search state at T= 377387.9096583559  and chi2= 16906047.402866952
#  /-acceptance  54.0 % at energy-step size  0.05386581486858087
# /--acceptance  56.99999999999999 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.22913046280543 minutes
# <--Equilibration reached. Updating and saving search state at T= 373614.0305617723  and chi2= 14516284.467040038
#  /-acceptance  36.0 % at energy-step size  0.05386581486858087
# /--acceptance  52.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.162460998694102 minutes
#  /-acceptance  39.0 % at energy-step size  0.04143524220660067
# /--acceptance  57.99999999999999 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.279641302426656 minutes
#  /-acceptance  4.0 % at energy-step size  0.03187326323584667
# /--acceptance  43.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.331798764069875 minutes
#  /-acceptance  0.0 % at energy-step size  0.024517894796805127
# /--acceptance  44.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.2260564486185705 minutes
#  /-acceptance  6.0 % at energy-step size  0.01885991907446548
# /--acceptance  45.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.213061555226644 minutes
#  /-acceptance  3.0 % at energy-step size  0.014507630057281139
# /--acceptance  52.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.308990279833476 minutes
#  /-acceptance  6.0 % at energy-step size  0.011159715428677799
# /--acceptance  56.99999999999999 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.147658809026082 minutes
#  /-acceptance  6.0 % at energy-step size  0.008584396483598307
# /--acceptance  42.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.029957548777262 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  0.006603381910460236
# /--acceptance  47.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.150579794247945 minutes
#  /-acceptance  5.0 % at energy-step size  0.005079524546507874
# /--acceptance  49.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.099610503514608 minutes
#  /-acceptance  5.0 % at energy-step size  0.003907326574236826
# /--acceptance  45.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.28211385011673 minutes
#  /-acceptance  3.0 % at energy-step size  0.0030056358263360196
# /--acceptance  43.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.1889677007993065 minutes
#  /-acceptance  2.0 % at energy-step size  0.002312027558720015
# /--acceptance  47.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.334510242938995 minutes
#  /-acceptance  2.0 % at energy-step size  0.0017784827374769346
# /--acceptance  48.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.383412655194601 minutes
#  /-acceptance  2.0 % at energy-step size  0.0013680636442130265
# /--acceptance  43.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.519585812091828 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  0.0010523566493946357
# /--acceptance  45.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.470367554823557 minutes
#  /-acceptance  6.0 % at energy-step size  0.0008095051149189505
# /--acceptance  45.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.4606904745101925 minutes
#  /-acceptance  6.0 % at energy-step size  0.0006226962422453466
# /--acceptance  47.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.260288814703624 minutes
#  /-acceptance  6.0 % at energy-step size  0.00047899710941949733
# /--acceptance  42.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.24528923034668 minutes
#  /-acceptance  5.0 % at energy-step size  0.0003684593149380749
# /--acceptance  44.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.38431944847107 minutes
#  /-acceptance  10.0 % at energy-step size  0.0002834302422600576
# /--acceptance  42.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.343567554155985 minutes
#  /-acceptance  3.0 % at energy-step size  0.00021802326327696736
# /--acceptance  43.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.426761349042256 minutes
#  /-acceptance  9.0 % at energy-step size  0.00016771020252074413
# /--acceptance  42.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.423436141014099 minutes
#  /-acceptance  12.0 % at energy-step size  0.0001290078480928801
# /--acceptance  51.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.024659144878387 minutes
#  /-acceptance  9.0 % at energy-step size  9.923680622529237e-05
# /--acceptance  44.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.412486346562703 minutes
#  /-acceptance  8.0 % at energy-step size  7.633600478868644e-05
# /--acceptance  37.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.298307510217031 minutes
#  /-acceptance  11.0 % at energy-step size  5.872000368360495e-05
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.368616890907288 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  4.516923360277304e-05
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.039323763052622 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  3.474556430982541e-05
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.188388462861379 minutes
#  /-acceptance  4.0 % at energy-step size  2.672735716140416e-05
# /--acceptance  61.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.252222339312236 minutes
#  /-acceptance  8.0 % at energy-step size  2.055950550877243e-05
# /--acceptance  37.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.177291703224182 minutes
#  /-acceptance  8.0 % at energy-step size  1.5815004237517252e-05
# /--acceptance  42.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.048199431101481 minutes
#  /-acceptance  6.0 % at energy-step size  1.2165387875013271e-05
# /--acceptance  43.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.404186908404032 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  9.357990673087132e-06
# /--acceptance  48.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.302286370595296 minutes
#  /-acceptance  26.0 % at energy-step size  7.198454363913178e-06
# /--acceptance  54.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.101382299264272 minutes
#  /-acceptance  12.0 % at energy-step size  5.537272587625521e-06
# /--acceptance  66.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.174335197607676 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  4.259440452019632e-06
# /--acceptance  44.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.414955580234528 minutes
#  /-acceptance  14.000000000000002 % at energy-step size  3.2764926553997166e-06
# /--acceptance  37.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.2408949613571165 minutes
#  /-acceptance  76.0 % at energy-step size  2.5203789656920897e-06
# /--acceptance  47.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.591460577646891 minutes
#  /-acceptance  13.0 % at energy-step size  3.2764926553997166e-06
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.522212707996369 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  2.5203789656920897e-06
# /--acceptance  46.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.290608644485474 minutes
#  /-acceptance  8.0 % at energy-step size  1.938753050532377e-06
# /--acceptance  59.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.100637571016947 minutes
#  /-acceptance  12.0 % at energy-step size  1.4913485004095205e-06
# /--acceptance  56.99999999999999 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.197824354966482 minutes
#  /-acceptance  9.0 % at energy-step size  1.1471911541611695e-06
# /--acceptance  47.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.28483335574468 minutes
#  /-acceptance  6.0 % at energy-step size  8.824547339701304e-07
# /--acceptance  50.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.430259644985199 minutes
#  /-acceptance  9.0 % at energy-step size  6.788113338231772e-07
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.19297178586324 minutes
#  /-acceptance  5.0 % at energy-step size  5.221625644793671e-07
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.283246473471324 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  4.0166351113797467e-07
# /--acceptance  54.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.310440361499786 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  3.089719316445959e-07
# /--acceptance  50.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.16151180267334 minutes
#  /-acceptance  8.0 % at energy-step size  2.3767071664968913e-07
# /--acceptance  54.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.502691400051117 minutes
#  /-acceptance  3.0 % at energy-step size  1.8282362819206856e-07
# /--acceptance  50.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  3.9803496837615966 minutes
#  /-acceptance  5.0 % at energy-step size  1.4063356014774505e-07
# /--acceptance  50.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.450496498743693 minutes
#  /-acceptance  2.0 % at energy-step size  1.0817966165211158e-07
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.002062757809957 minutes
#  /-acceptance  4.0 % at energy-step size  8.321512434777813e-08
# /--acceptance  51.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.465617763996124 minutes
#  /-acceptance  4.0 % at energy-step size  6.401163411367549e-08
# /--acceptance  57.99999999999999 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.438563307126363 minutes
#  /-acceptance  8.0 % at energy-step size  4.9239718548981143e-08
# /--acceptance  52.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.282612140973409 minutes
#  /-acceptance  8.0 % at energy-step size  3.787670657613934e-08
# /--acceptance  56.00000000000001 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.422995356718699 minutes
#  /-acceptance  13.0 % at energy-step size  2.9135928135491798e-08
# /--acceptance  47.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.237944293022156 minutes
#  /-acceptance  5.0 % at energy-step size  2.2412252411916768e-08
# /--acceptance  56.99999999999999 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.323069985707601 minutes
#  /-acceptance  10.0 % at energy-step size  1.7240194163012897e-08
# /--acceptance  52.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.426496907075246 minutes
#  /-acceptance  10.0 % at energy-step size  1.3261687817702227e-08
# /--acceptance  46.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.43049468199412 minutes
#  /-acceptance  9.0 % at energy-step size  1.0201298321309406e-08
# /--acceptance  56.00000000000001 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.214048612117767 minutes
#  /-acceptance  4.0 % at energy-step size  7.847152554853388e-09
# /--acceptance  46.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.246754705905914 minutes
#  /-acceptance  5.0 % at energy-step size  6.036271196041068e-09
# /--acceptance  55.00000000000001 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.1156273563702905 minutes
#  /-acceptance  2.0 % at energy-step size  4.643285535416206e-09
# /--acceptance  50.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.025934628645579 minutes
#  /-acceptance  3.0 % at energy-step size  3.571758104166312e-09
# /--acceptance  43.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.2695140441258745 minutes
#  /-acceptance  4.0 % at energy-step size  2.7475062339740864e-09
# /--acceptance  52.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.434051716327668 minutes
#  /-acceptance  21.0 % at energy-step size  2.1134663338262204e-09
# /--acceptance  62.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.318834380308787 minutes
#  /-acceptance  89.0 % at energy-step size  1.6257433337124771e-09
# /--acceptance  49.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.245096349716187 minutes
#  /-acceptance  62.0 % at energy-step size  2.1134663338262204e-09
# /--acceptance  38.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.355261826515198 minutes
#  /-acceptance  72.0 % at energy-step size  2.747506233974087e-09
# /--acceptance  48.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.479546292622884 minutes
#  /-acceptance  20.0 % at energy-step size  3.571758104166313e-09
# /--acceptance  44.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.31770662466685 minutes
#  /-acceptance  6.0 % at energy-step size  2.747506233974087e-09
# /--acceptance  60.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.356616266568502 minutes
#  /-acceptance  46.0 % at energy-step size  2.1134663338262204e-09
# /--acceptance  57.99999999999999 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.268875988324483 minutes
# <--Equilibration reached. Updating and saving search state at T= 369877.8902561546  and chi2= 21051630.953734852
#  /-acceptance  22.0 % at energy-step size  2.1134663338262204e-09
# /--acceptance  54.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.343464227517446 minutes
#  /-acceptance  12.0 % at energy-step size  1.6257433337124771e-09
# /--acceptance  60.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  3.907886997858683 minutes
#  /-acceptance  8.0 % at energy-step size  1.2505717951634438e-09
# /--acceptance  52.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.162995115915934 minutes
#  /-acceptance  5.0 % at energy-step size  9.619783039718799e-10
# /--acceptance  62.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.518240078290304 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  7.399833107475999e-10
# /--acceptance  41.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.185166056950887 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  5.692179313443076e-10
# /--acceptance  37.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.4549545804659525 minutes
#  /-acceptance  12.0 % at energy-step size  4.378599471879289e-10
# /--acceptance  40.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.198768230279287 minutes
#  /-acceptance  6.0 % at energy-step size  3.368153439907145e-10
# /--acceptance  42.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.374406496683757 minutes
#  /-acceptance  11.0 % at energy-step size  2.5908872614670346e-10
# /--acceptance  49.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.424650883674621 minutes
#  /-acceptance  6.0 % at energy-step size  1.9929902011284882e-10
# /--acceptance  51.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.2158329884211225 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  1.5330693854834523e-10
# /--acceptance  53.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.423439594109853 minutes
#  /-acceptance  8.0 % at energy-step size  1.1792841426795787e-10
# /--acceptance  56.00000000000001 %  at barrier-busting power  0.4733727810650888
# |--Time cost  3.90086315870285 minutes
#  /-acceptance  9.0 % at energy-step size  9.071416482150605e-11
# /--acceptance  47.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.0753642598787945 minutes
#  /-acceptance  11.0 % at energy-step size  6.978012678577389e-11
# /--acceptance  50.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  3.844165555636088 minutes
#  /-acceptance  5.0 % at energy-step size  5.367702060444145e-11
# /--acceptance  47.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.15478740533193 minutes
#  /-acceptance  6.0 % at energy-step size  4.1290015849570346e-11
# /--acceptance  49.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.599858772754669 minutes
#  /-acceptance  6.0 % at energy-step size  3.176155065351565e-11
# /--acceptance  52.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.823432981967926 minutes
#  /-acceptance  9.0 % at energy-step size  2.4431962041165886e-11
# /--acceptance  60.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.74566338857015 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  1.8793816954742988e-11
# /--acceptance  50.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.200496582190196 minutes
#  /-acceptance  4.0 % at energy-step size  1.4456782272879221e-11
# /--acceptance  62.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.121283773581187 minutes
#  /-acceptance  6.0 % at energy-step size  1.1120601748368631e-11
# /--acceptance  50.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.164247091611227 minutes
#  /-acceptance  8.0 % at energy-step size  8.554309037206639e-12
# /--acceptance  33.0 %  at barrier-busting power  0.6153846153846154
# |--Time cost  4.299997341632843 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  6.580237720928184e-12
# /--acceptance  46.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.739277458190918 minutes
#  /-acceptance  4.0 % at energy-step size  5.061721323790911e-12
# /--acceptance  41.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.892712422211965 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  3.89363178753147e-12
# /--acceptance  49.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.749711000919342 minutes
#  /-acceptance  5.0 % at energy-step size  2.995101375024207e-12
# /--acceptance  46.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.986721241474152 minutes
#  /-acceptance  8.0 % at energy-step size  2.3039241346340055e-12
# /--acceptance  47.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  5.009640940030416 minutes
#  /-acceptance  9.0 % at energy-step size  1.7722493343338504e-12
# /--acceptance  40.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  5.175390283266704 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  1.3632687187183464e-12
# /--acceptance  40.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.8912584702173865 minutes
#  /-acceptance  6.0 % at energy-step size  1.0486682451679586e-12
# /--acceptance  50.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  6.38694258928299 minutes
#  /-acceptance  7.000000000000001 % at energy-step size  8.066678808984297e-13
# /--acceptance  60.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  6.686640659968059 minutes
#  /-acceptance  9.0 % at energy-step size  6.205137545372536e-13
# /--acceptance  50.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  6.316248679161072 minutes
#  /-acceptance  9.0 % at energy-step size  4.773182727209643e-13
# /--acceptance  51.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  5.469077754020691 minutes
#  /-acceptance  22.0 % at energy-step size  3.671679020930494e-13
# /--acceptance  50.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  5.420537702242533 minutes
#  /-acceptance  9.0 % at energy-step size  2.824368477638842e-13
# /--acceptance  49.0 %  at barrier-busting power  0.4733727810650888
# |--Time cost  4.7179466446240745 minutes

# %% [markdown]
# ## Restarting an aborted optimization run

# %%
t1 = time()

fileResults = path+"DEP\\Run_"+run_def+"_Search_State.txt"
fileMonitor = path+"DEP\\Run_"+run_def+"_Search_Monitor.txt"
fileInitMonitor = path+"DEP\\Run_"+run_def+"_Initiation_Monitor.txt"

#fileResults = path+"DEP\\test_Results_bb.txt"
#fileMonitor = path+"DEP\\test_Monitor_bb.txt"
#fileInitMonitor = path+"DEP\\test_InitMonitor_bb.txt"

best_fit = SAfit.restart_SA_DEP(xdata=xdata,
                                ydata=ydata,
                                yerr=yerr,
                                lwrbnd=lower_bnd,
                                upbnd=upper_bnd,
                                objective_function=myObjectiveFunc,
                                objective_function_args=funcArgs,
                                tol=1E-5,
                                Tfinal=0.0,
                                adjust_factor=1.3,
                                cooling_rate=0.99,
                                N_int=400,
                                AR_low=40,
                                AR_high=60,
                                use_multiprocessing=True,
                                nprocs=19,  # HPC05 has computers with 20 cores. 1 core reserved for THIS function
                                output_file_results=fileResults,
                                output_file_monitor=fileMonitor,
                                output_file_init_monitor=fileInitMonitor)

t2 = time()

# the following line will get printed into a specific text file when running on cluster.
print("Time elapsed: ", (t2-t1)/3600., "hrs")
# Out:
# ====================================================================================================================================
# > Initiating cool-down at
# >--temp:   3572683.8443474737
# >--energy step:   2.055950550877243e-05
# >--bb power step:   0.020318098186031492
# ------------------------------------------------------------------------------------------------------------------------------------
# |-appending run to C:\Users\mdepk\Documents\CRISPR_kinetic_model\DEP\Run_20200920-1312_Search_State.txt
#  /-acceptance  2.75 % at energy-step size  2.055950550877243e-05
# /--acceptance  38.25 %  at barrier-busting power  0.020318098186031492
# |--Time cost  38.565847754478455 minutes
#  /-acceptance  1.7500000000000002 % at energy-step size  1.5815004237517252e-05
# /--acceptance  36.75 %  at barrier-busting power  0.015629306296947303
# |--Time cost  38.77649845679601 minutes
#  /-acceptance  1.5 % at energy-step size  1.2165387875013271e-05
# /--acceptance  32.75 %  at barrier-busting power  0.012022543305344078
# |--Time cost  39.41862743695577 minutes
#  /-acceptance  1.5 % at energy-step size  9.357990673087132e-06
# /--acceptance  35.75 %  at barrier-busting power  0.00924811023488006
# |--Time cost  37.89843403100967 minutes

# %% [markdown]
# ## Loading some fits to see how it went

# %%
#the on-target 
targetE = 'GACGCATAAAGATGAGACGCTGG'

file_parameters =   '/Users/mdepk/Documents/CRISPR_kinetic_model/DEP/test_Results_old.txt'

fatch_solution="best_solution"

epsilon_list= []

for n in 0:89:
        Cas_params, dCas_params, epsilon, forward_rates, kon, kf, kcat= kinpar.kinetic_parameters(file_parameters,
                                                                                          ID_Cas="Clv_Saturated_general_energies_v2",
                                                                                          ID_dCas="general_energies_no_kPR",
                                                                                          concentration_nM=10.,
                                                                                          nmbr_fit_params=44)
        epsilon_list.append(epsilon)

landscape_on_target = free_energy_landscape.plot_landscape(guide=targetE,target=targetE,epsilon=epsilon, 
                                                          Cas=Cas9,show_plot=True);

# %%
# !True

# %%
fig, ((ax1,ax2))=plt.sub
